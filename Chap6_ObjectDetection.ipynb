# %% [markdown]
# # 安裝/下載

# %% [markdown]
# 安裝ImageAI
#
# 取得RetinaNet, YOLO, Tiny_Yolo三個模型

# %%
# !pip install imageai
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/retinanet_resnet50_fpn_coco-eeacb38b.pth
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/yolov3.pt
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/tiny-yolov3.pt
# Out:
# Collecting imageai
#   Downloading imageai-3.0.3-py3-none-any.whl.metadata (340 bytes)
# Downloading imageai-3.0.3-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: imageai
# Successfully installed imageai-3.0.3
# --2025-12-02 02:40:39--  https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/retinanet_resnet50_fpn_coco-eeacb38b.pth
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/125932201/59e23251-eca0-4ba3-9018-69831ceb9c07?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A36%3A09Z&rscd=attachment%3B+filename%3Dretinanet_resnet50_fpn_coco-eeacb38b.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A35%3A20Z&ske=2025-12-02T03%3A36%3A09Z&sks=b&skv=2018-11-09&sig=2DiS2%2BRTlQaqc1fAg%2BHVfJG0QQfgmTn9SGWb3n7Acp0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0Njg0MCwibmJmIjoxNzY0NjQzMjQwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1fVLk4hkf3guT6nt8UtTlF_eAfaoKojmI3ri0oqC98s&response-content-disposition=attachment%3B%20filename%3Dretinanet_resnet50_fpn_coco-eeacb38b.pth&response-content-type=application%2Foctet-stream [following]
# --2025-12-02 02:40:40--  https://release-assets.githubusercontent.com/github-production-release-asset/125932201/59e23251-eca0-4ba3-9018-69831ceb9c07?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A36%3A09Z&rscd=attachment%3B+filename%3Dretinanet_resnet50_fpn_coco-eeacb38b.pth&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A35%3A20Z&ske=2025-12-02T03%3A36%3A09Z&sks=b&skv=2018-11-09&sig=2DiS2%2BRTlQaqc1fAg%2BHVfJG0QQfgmTn9SGWb3n7Acp0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0Njg0MCwibmJmIjoxNzY0NjQzMjQwLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1fVLk4hkf3guT6nt8UtTlF_eAfaoKojmI3ri0oqC98s&response-content-disposition=attachment%3B%20filename%3Dretinanet_resnet50_fpn_coco-eeacb38b.pth&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136595076 (130M) [application/octet-stream]
# Saving to: ‘retinanet_resnet50_fpn_coco-eeacb38b.pth’
#
# retinanet_resnet50_ 100%[===================>] 130.27M   175MB/s    in 0.7s
#
# 2025-12-02 02:40:41 (175 MB/s) - ‘retinanet_resnet50_fpn_coco-eeacb38b.pth’ saved [136595076/136595076]
#
# --2025-12-02 02:40:41--  https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/yolov3.pt
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/125932201/adc7efe4-b3ac-4710-8a05-0bfefa255bae?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A36%3A20Z&rscd=attachment%3B+filename%3Dyolov3.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A35%3A35Z&ske=2025-12-02T03%3A36%3A20Z&sks=b&skv=2018-11-09&sig=f6pWJkV6im8R30Y8Q%2BDufFskBeGkAQMy76YbFKmXIis%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0Njg0MSwibmJmIjoxNzY0NjQzMjQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.kAGFwh_yLZ4dU_4mmjXIxru4QCtsz6-Y52qljNcqdGU&response-content-disposition=attachment%3B%20filename%3Dyolov3.pt&response-content-type=application%2Foctet-stream [following]
# --2025-12-02 02:40:41--  https://release-assets.githubusercontent.com/github-production-release-asset/125932201/adc7efe4-b3ac-4710-8a05-0bfefa255bae?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A36%3A20Z&rscd=attachment%3B+filename%3Dyolov3.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A35%3A35Z&ske=2025-12-02T03%3A36%3A20Z&sks=b&skv=2018-11-09&sig=f6pWJkV6im8R30Y8Q%2BDufFskBeGkAQMy76YbFKmXIis%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0Njg0MSwibmJmIjoxNzY0NjQzMjQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.kAGFwh_yLZ4dU_4mmjXIxru4QCtsz6-Y52qljNcqdGU&response-content-disposition=attachment%3B%20filename%3Dyolov3.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248148565 (237M) [application/octet-stream]
# Saving to: ‘yolov3.pt’
#
# yolov3.pt           100%[===================>] 236.65M   154MB/s    in 1.5s
#
# 2025-12-02 02:40:43 (154 MB/s) - ‘yolov3.pt’ saved [248148565/248148565]
#
# --2025-12-02 02:40:43--  https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/tiny-yolov3.pt
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/125932201/c34913f1-8a4f-4b7d-a864-3abf772e3515?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A36%3A57Z&rscd=attachment%3B+filename%3Dtiny-yolov3.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A36%3A09Z&ske=2025-12-02T03%3A36%3A57Z&sks=b&skv=2018-11-09&sig=J4Vxb9Ce7Ewh2I6lEWFe75WXgNCJthd8I3msszT2UpU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0NTA0MywibmJmIjoxNzY0NjQzMjQzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.iohyRJKERcd7dUo1UCKRtOPMTOFSCBF0LBEOkyvlEio&response-content-disposition=attachment%3B%20filename%3Dtiny-yolov3.pt&response-content-type=application%2Foctet-stream [following]
# --2025-12-02 02:40:43--  https://release-assets.githubusercontent.com/github-production-release-asset/125932201/c34913f1-8a4f-4b7d-a864-3abf772e3515?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A36%3A57Z&rscd=attachment%3B+filename%3Dtiny-yolov3.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A36%3A09Z&ske=2025-12-02T03%3A36%3A57Z&sks=b&skv=2018-11-09&sig=J4Vxb9Ce7Ewh2I6lEWFe75WXgNCJthd8I3msszT2UpU%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0NTA0MywibmJmIjoxNzY0NjQzMjQzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.iohyRJKERcd7dUo1UCKRtOPMTOFSCBF0LBEOkyvlEio&response-content-disposition=attachment%3B%20filename%3Dtiny-yolov3.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35457043 (34M) [application/octet-stream]
# Saving to: ‘tiny-yolov3.pt’
#
# tiny-yolov3.pt      100%[===================>]  33.81M   198MB/s    in 0.2s
#
# 2025-12-02 02:40:43 (198 MB/s) - ‘tiny-yolov3.pt’ saved [35457043/35457043]

# %%
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img0.jpg
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img1.jpg
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img2.jpg
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img3.jpg
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img4.jpg
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img5.jpg

# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_video0.mp4
# !wget https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_video1.mp4
# Out:
# --2025-12-02 03:38:46--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img0.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156833 (153K) [image/jpeg]
# Saving to: ‘OD_img0.jpg.1’
#
# OD_img0.jpg.1       100%[===================>] 153.16K  --.-KB/s    in 0.02s
#
# 2025-12-02 03:38:46 (8.53 MB/s) - ‘OD_img0.jpg.1’ saved [156833/156833]
#
# --2025-12-02 03:38:46--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img1.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76767 (75K) [image/jpeg]
# Saving to: ‘OD_img1.jpg.1’
#
# OD_img1.jpg.1       100%[===================>]  74.97K  --.-KB/s    in 0.009s
#
# 2025-12-02 03:38:46 (8.01 MB/s) - ‘OD_img1.jpg.1’ saved [76767/76767]
#
# --2025-12-02 03:38:46--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img2.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69286 (68K) [image/jpeg]
# Saving to: ‘OD_img2.jpg.1’
#
# OD_img2.jpg.1       100%[===================>]  67.66K  --.-KB/s    in 0.008s
#
# 2025-12-02 03:38:47 (8.70 MB/s) - ‘OD_img2.jpg.1’ saved [69286/69286]
#
# --2025-12-02 03:38:47--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img3.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155447 (152K) [image/jpeg]
# Saving to: ‘OD_img3.jpg.1’
#
# OD_img3.jpg.1       100%[===================>] 151.80K  --.-KB/s    in 0.01s
#
# 2025-12-02 03:38:47 (10.2 MB/s) - ‘OD_img3.jpg.1’ saved [155447/155447]
#
# --2025-12-02 03:38:47--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img4.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54576 (53K) [image/jpeg]
# Saving to: ‘OD_img4.jpg.1’
#
# OD_img4.jpg.1       100%[===================>]  53.30K  --.-KB/s    in 0.008s
#
# 2025-12-02 03:38:47 (6.37 MB/s) - ‘OD_img4.jpg.1’ saved [54576/54576]
#
# --2025-12-02 03:38:47--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_img5.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 171799 (168K) [image/jpeg]
# Saving to: ‘OD_img5.jpg’
#
# OD_img5.jpg         100%[===================>] 167.77K  --.-KB/s    in 0.02s
#
# 2025-12-02 03:38:47 (8.42 MB/s) - ‘OD_img5.jpg’ saved [171799/171799]
#
# --2025-12-02 03:38:48--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_video0.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22811445 (22M) [application/octet-stream]
# Saving to: ‘OD_video0.mp4.1’
#
# OD_video0.mp4.1     100%[===================>]  21.75M  --.-KB/s    in 0.1s
#
# 2025-12-02 03:38:48 (213 MB/s) - ‘OD_video0.mp4.1’ saved [22811445/22811445]
#
# --2025-12-02 03:38:49--  https://raw.githubusercontent.com/limin-liu-tw/datasets/refs/heads/main/OD_video1.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16399265 (16M) [application/octet-stream]
# Saving to: ‘OD_video1.mp4.1’
#
# OD_video1.mp4.1     100%[===================>]  15.64M  --.-KB/s    in 0.09s
#
# 2025-12-02 03:38:49 (180 MB/s) - ‘OD_video1.mp4.1’ saved [16399265/16399265]

# %%
# !ls -la
# Out:
# total 449188
# drwxr-xr-x 1 root root      4096 Dec  2 02:40 .
# drwxr-xr-x 1 root root      4096 Dec  2 02:38 ..
# drwxr-xr-x 4 root root      4096 Nov 20 14:30 .config
# drwx------ 5 root root      4096 Dec  2 02:39 drive
# -rw-r--r-- 1 root root    156833 Dec  2 02:40 OD_img0.jpg
# -rw-r--r-- 1 root root     76767 Dec  2 02:40 OD_img1.jpg
# -rw-r--r-- 1 root root     69286 Dec  2 02:40 OD_img2.jpg
# -rw-r--r-- 1 root root    155447 Dec  2 02:40 OD_img3.jpg
# -rw-r--r-- 1 root root     54576 Dec  2 02:40 OD_img4.jpg
# -rw-r--r-- 1 root root  22811445 Dec  2 02:40 OD_video0.mp4
# -rw-r--r-- 1 root root  16399265 Dec  2 02:40 OD_video1.mp4
# -rw-r--r-- 1 root root 136595076 Nov 10  2022 retinanet_resnet50_fpn_coco-eeacb38b.pth
# drwxr-xr-x 1 root root      4096 Nov 20 14:30 sample_data
# -rw-r--r-- 1 root root  35457043 Nov 10  2022 tiny-yolov3.pt
# -rw-r--r-- 1 root root 248148565 Nov 10  2022 yolov3.pt

# %% [markdown]
# # 匯入套件，定義變數

# %%
from PIL import Image
from google.colab import files
import matplotlib.pyplot as plt
from imageai.Detection import ObjectDetection
from imageai.Detection import VideoObjectDetection
from imageai.Detection.Custom import DetectionModelTrainer
from imageai.Detection.Custom import CustomObjectDetection

mdl_res50= "/content/retinanet_resnet50_fpn_coco-eeacb38b.pth"
mdl_yolo = "/content/yolov3.pt"
mdl_yolot= "/content/tiny-yolov3.pt"

# %% [markdown]
# # 辨識照片中的物件

# %% [markdown]
# 載入三個模型

# %%
def createDetector(model_path, model_type):
  detector = ObjectDetection()
  if model_type == "retinanet":
    detector.setModelTypeAsRetinaNet()
  elif model_type == "yolo":
    detector.setModelTypeAsYOLOv3()
  else:
    detector.setModelTypeAsTinyYOLOv3()
  detector.setModelPath(model_path)
  detector.loadModel()

dtr1 = createDetector(mdl_res50, "retinanet")
dtr2 = createDetector(mdl_yolo, "yolo")
dtr3 = createDetector(mdl_yolot, "tiny-yolo")

# %%
dtr1 = ObjectDetection()
dtr1.setModelTypeAsRetinaNet()
dtr1.setModelPath(mdl_res50)
dtr1.loadModel()
dtr2 = ObjectDetection()
dtr2.setModelTypeAsYOLOv3()
dtr2.setModelPath(mdl_yolo)
dtr2.loadModel()
dtr3 = ObjectDetection()
dtr3.setModelTypeAsTinyYOLOv3()
dtr3.setModelPath(mdl_yolot)
dtr3.loadModel()

# %%
def process_one(inFile, outFile, detector, perc=50, types=[]):
  # 1. 偵測物件
  dtr = detector.detectObjectsFromImage(input_image=inFile,
    output_image_path=outFile, minimum_percentage_probability=perc)
  # 2. 輸出文字說明
  for i in dtr:
   if i["percentage_probability"] >= perc:
    n, p, b = i["name"], i["percentage_probability"], i["box_points"]
    if (len(types)==0 or (n in types)): print("{}: {}: {}".format(n, p, b))
  # 3. 顯示結果圖片
  plt.axis('off')
  _=plt.imshow(Image.open(outFile))
  _=plt.show()

# %%
process_one("OD_img0.jpg", "result1.png", dtr1)
# Out:
# person: 96.51: [182, 45, 524, 615]
# vase: 54.36: [234, 436, 450, 563]
# potted plant: 52.98: [173, 320, 482, 558]

# %%
process_one("OD_img0.jpg", "result2.png", dtr2)
# Out:
# person: 100.0: [184, 41, 521, 576]
# bicycle: 98.68: [189, 339, 482, 615]

# %%
process_one("OD_img1.jpg", "result3.png", dtr2)
# Out:
# person: 100.0: [58, 81, 125, 310]
# person: 100.0: [168, 56, 247, 271]
# person: 100.0: [116, 73, 178, 302]
# car: 98.14: [216, 104, 467, 298]
# dog: 99.99: [146, 238, 216, 312]

# %%
process_one("OD_img2.jpg", "result4.png", dtr3)
# Out:
# person: 99.85: [136, 16, 211, 307]
# person: 99.59: [182, 27, 252, 300]
# person: 99.75: [83, 120, 139, 294]
# person: 99.67: [99, 144, 126, 268]
# car: 82.57: [216, 99, 507, 326]

# %% [markdown]
# # 辨識影片中的物件

# %%
dtr4 = VideoObjectDetection()
dtr4.setModelTypeAsTinyYOLOv3() # dtr4.setModelTypeAsYOLOv3()
dtr4.setModelPath(mdl_yolot)    # dtr4.setModelPath(mdl_yolo)
dtr4.loadModel()

# %%
# !ls -la OD*.mp4
# Out:
# -rw-r--r-- 1 root root 22811445 Dec  2 00:39 OD_video0.mp4
# -rw-r--r-- 1 root root 16399265 Dec  2 00:39 OD_video1.mp4

# %%
_=dtr4.detectObjectsFromVideo(input_file_path="OD_video0.mp4",
      frames_per_second=30,   output_file_path="OD_video0_result",
      minimum_percentage_probability=20,log_progress=False)

# %%
#files.download('OD_video0_result.mp4')

# %%
_=dtr4.detectObjectsFromVideo(input_file_path="OD_video1.mp4",
      frames_per_second=30,   output_file_path="OD_video1_result",
      minimum_percentage_probability=20,log_progress=False)

# %%
#files.download('OD_video1_result.mp4')

# %% [markdown]
# # 解壓縮訓練數據

# %%
# !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/test-resources-v3/hololens-yolo.zip
# !unzip -qq hololens-yolo.zip
# Out:
# --2025-12-02 02:41:29--  https://github.com/OlafenwaMoses/ImageAI/releases/download/test-resources-v3/hololens-yolo.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/125932201/afeab43f-b3d2-4a7c-8805-3cff2d3aafdd?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A41%3A05Z&rscd=attachment%3B+filename%3Dhololens-yolo.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A40%3A35Z&ske=2025-12-02T03%3A41%3A05Z&sks=b&skv=2018-11-09&sig=3tMoePiZBALz%2BXRvZB2THjGie1GHi9SSf9R8kUdybgo%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0MzU4OSwibmJmIjoxNzY0NjQzMjg5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.rSslQv1IVT2XKxloV-8m-lr9M2lujJM6Hv4mrXKs4gQ&response-content-disposition=attachment%3B%20filename%3Dhololens-yolo.zip&response-content-type=application%2Foctet-stream [following]
# --2025-12-02 02:41:29--  https://release-assets.githubusercontent.com/github-production-release-asset/125932201/afeab43f-b3d2-4a7c-8805-3cff2d3aafdd?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-02T03%3A41%3A05Z&rscd=attachment%3B+filename%3Dhololens-yolo.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-02T02%3A40%3A35Z&ske=2025-12-02T03%3A41%3A05Z&sks=b&skv=2018-11-09&sig=3tMoePiZBALz%2BXRvZB2THjGie1GHi9SSf9R8kUdybgo%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NDY0MzU4OSwibmJmIjoxNzY0NjQzMjg5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.rSslQv1IVT2XKxloV-8m-lr9M2lujJM6Hv4mrXKs4gQ&response-content-disposition=attachment%3B%20filename%3Dhololens-yolo.zip&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2266870 (2.2M) [application/octet-stream]
# Saving to: ‘hololens-yolo.zip’
#
# hololens-yolo.zip   100%[===================>]   2.16M  --.-KB/s    in 0.04s
#
# 2025-12-02 02:41:29 (61.5 MB/s) - ‘hololens-yolo.zip’ saved [2266870/2266870]

# %%
# !du hololens-yolo
# Out:
# 564	hololens-yolo/validation/images
# 244	hololens-yolo/validation/annotations
# 812	hololens-yolo/validation
# 2104	hololens-yolo/train/images
# 976	hololens-yolo/train/annotations
# 3084	hololens-yolo/train
# 3900	hololens-yolo

# %%
trainer = DetectionModelTrainer()
trainer.setModelTypeAsTinyYOLOv3()
trainer.setDataDirectory(data_directory="hololens-yolo")
trainer.setTrainConfig(object_names_array=["hololens-yolo"], batch_size=4,
                  num_experiments=200, train_from_pretrained_model=mdl_yolot)
trainer.trainModel()
# Out:
# /usr/local/lib/python3.12/dist-packages/imageai/Detection/Custom/__init__.py:47: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.__scaler = amp.GradScaler(enabled=self.__cuda)
# Generating anchor boxes for training images...
# thr=0.25: 1.0000 best possible recall, 4.72 anchors past thr
# n=6, img_size=416, metric_all=0.469/0.820-mean/best, past_thr=0.549-mean:
# ====================
# Pretrained YOLOv3 model loaded to initialize weights
# ====================
# Epoch 1/200
# ----------
# Train:
# 0it [00:00, ?it/s]/usr/local/lib/python3.12/dist-packages/imageai/Detection/Custom/__init__.py:269: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(enabled=self.__cuda):
# 60it [00:05, 10.09it/s]
#     box loss-> 0.06856, object loss-> 0.23796, class loss-> 0.00000
# Validation:
# 30it [00:49,  1.65s/it]
#     recall: 0.085714 precision: 0.030931 mAP@0.5: 0.005430, mAP@0.5-0.95: 0.000914
#
# Epoch 2/200
# ----------
# Train:
# 60it [00:03, 19.30it/s]
#     box loss-> 0.06303, object loss-> 0.05901, class loss-> 0.00000
# Validation:
# 30it [00:42,  1.40s/it]
#     recall: 0.185714 precision: 0.058268 mAP@0.5: 0.021777, mAP@0.5-0.95: 0.003461
#
# Epoch 3/200
# ----------
# Train:
# 60it [00:02, 24.80it/s]
#     box loss-> 0.05845, object loss-> 0.05456, class loss-> 0.00000
# Validation:
# 30it [00:38,  1.28s/it]
#     recall: 0.314286 precision: 0.186775 mAP@0.5: 0.122643, mAP@0.5-0.95: 0.024377
#
# Epoch 4/200
# ----------
# Train:
# 60it [00:02, 24.52it/s]
#     box loss-> 0.05554, object loss-> 0.04993, class loss-> 0.00000
# Validation:
# 30it [00:36,  1.23s/it]
#     recall: 0.271429 precision: 0.207821 mAP@0.5: 0.137744, mAP@0.5-0.95: 0.025430
#
# Epoch 5/200
# ----------
# Train:
# 60it [00:02, 25.85it/s]
#     box loss-> 0.05229, object loss-> 0.04706, class loss-> 0.00000
# Validation:
# 30it [00:33,  1.13s/it]
#     recall: 0.357143 precision: 0.204303 mAP@0.5: 0.161911, mAP@0.5-0.95: 0.036186
#
# Epoch 6/200
# ----------
# Train:
# 60it [00:02, 24.79it/s]
#     box loss-> 0.04905, object loss-> 0.04446, class loss-> 0.00000
# Validation:
# 30it [00:31,  1.04s/it]
#     recall: 0.342857 precision: 0.269210 mAP@0.5: 0.213249, mAP@0.5-0.95: 0.047301
#
# Epoch 7/200
# ----------
# Train:
# 60it [00:02, 22.33it/s]
#     box loss-> 0.04594, object loss-> 0.04253, class loss-> 0.00000
# Validation:
# 30it [00:27,  1.10it/s]
#     recall: 0.328571 precision: 0.383327 mAP@0.5: 0.284141, mAP@0.5-0.95: 0.062947
#
# Epoch 8/200
# ----------
# Train:
# 60it [00:02, 26.06it/s]
#     box loss-> 0.04279, object loss-> 0.04110, class loss-> 0.00000
# Validation:
# 30it [00:25,  1.19it/s]
#     recall: 0.428571 precision: 0.329616 mAP@0.5: 0.320066, mAP@0.5-0.95: 0.066272
#
# Epoch 9/200
# ----------
# Train:
# 60it [00:02, 25.34it/s]
#     box loss-> 0.04051, object loss-> 0.03971, class loss-> 0.00000
# Validation:
# 30it [00:24,  1.25it/s]
#     recall: 0.571429 precision: 0.328776 mAP@0.5: 0.344350, mAP@0.5-0.95: 0.073136
#
# Epoch 10/200
# ----------
# Train:
# 60it [00:02, 24.74it/s]
#     box loss-> 0.04058, object loss-> 0.03742, class loss-> 0.00000
# Validation:
# 30it [00:20,  1.43it/s]
#     recall: 0.557143 precision: 0.295088 mAP@0.5: 0.315581, mAP@0.5-0.95: 0.064144
#
# Epoch 11/200
# ----------
# Train:
# 60it [00:02, 25.76it/s]
#     box loss-> 0.04020, object loss-> 0.03568, class loss-> 0.00000
# Validation:
# 30it [00:16,  1.84it/s]
#     recall: 0.442857 precision: 0.346993 mAP@0.5: 0.300819, mAP@0.5-0.95: 0.054454
#
# Epoch 12/200
# ----------
# Train:
# 60it [00:02, 24.27it/s]
#     box loss-> 0.03826, object loss-> 0.03446, class loss-> 0.00000
# Validation:
# 30it [00:15,  1.99it/s]
#     recall: 0.500000 precision: 0.371524 mAP@0.5: 0.339050, mAP@0.5-0.95: 0.072887
#
# Epoch 13/200
# ----------
# Train:
# 60it [00:02, 24.40it/s]
#     box loss-> 0.03617, object loss-> 0.03291, class loss-> 0.00000
# Validation:
# 30it [00:13,  2.16it/s]
#     recall: 0.485714 precision: 0.465383 mAP@0.5: 0.381614, mAP@0.5-0.95: 0.105821
#
# Epoch 14/200
# ----------
# Train:
# 60it [00:02, 25.28it/s]
#     box loss-> 0.03492, object loss-> 0.03177, class loss-> 0.00000
# Validation:
# 30it [00:11,  2.56it/s]
#     recall: 0.614286 precision: 0.398018 mAP@0.5: 0.377333, mAP@0.5-0.95: 0.106498
#
# Epoch 15/200
# ----------
# Train:
# 60it [00:02, 25.57it/s]
#     box loss-> 0.03568, object loss-> 0.03216, class loss-> 0.00000
# Validation:
# 30it [00:10,  2.73it/s]
#     recall: 0.557143 precision: 0.541440 mAP@0.5: 0.426657, mAP@0.5-0.95: 0.134824
#
# Epoch 16/200
# ----------
# Train:
# 60it [00:02, 25.52it/s]
#     box loss-> 0.03394, object loss-> 0.03003, class loss-> 0.00000
# Validation:
# 30it [00:09,  3.06it/s]
#     recall: 0.614286 precision: 0.355296 mAP@0.5: 0.341511, mAP@0.5-0.95: 0.111120
#
# Epoch 17/200
# ----------
# Train:
# 60it [00:02, 25.67it/s]
#     box loss-> 0.03156, object loss-> 0.02863, class loss-> 0.00000
# Validation:
# 30it [00:08,  3.37it/s]
#     recall: 0.428571 precision: 0.599227 mAP@0.5: 0.474846, mAP@0.5-0.95: 0.115765
#
# Epoch 18/200
# ----------
# Train:
# 60it [00:02, 25.51it/s]
#     box loss-> 0.03139, object loss-> 0.02913, class loss-> 0.00000
# Validation:
# 30it [00:08,  3.61it/s]
#     recall: 0.542857 precision: 0.505912 mAP@0.5: 0.504614, mAP@0.5-0.95: 0.157440
#
# Epoch 19/200
# ----------
# Train:
# 60it [00:02, 25.60it/s]
#     box loss-> 0.03239, object loss-> 0.02844, class loss-> 0.00000
# Validation:
# 30it [00:05,  5.02it/s]
#     recall: 0.641911 precision: 0.356802 mAP@0.5: 0.398913, mAP@0.5-0.95: 0.081607
#
# Epoch 20/200
# ----------
# Train:
# 60it [00:02, 23.84it/s]
#     box loss-> 0.03277, object loss-> 0.02950, class loss-> 0.00000
# Validation:
# 30it [00:06,  4.81it/s]
#     recall: 0.585714 precision: 0.585441 mAP@0.5: 0.562621, mAP@0.5-0.95: 0.187789
#
# Epoch 21/200
# ----------
# Train:
# 60it [00:02, 25.93it/s]
#     box loss-> 0.02652, object loss-> 0.02533, class loss-> 0.00000
# Validation:
# 30it [00:05,  5.40it/s]
#     recall: 0.657143 precision: 0.638520 mAP@0.5: 0.620745, mAP@0.5-0.95: 0.203366
#
# Epoch 22/200
# ----------
# Train:
# 60it [00:02, 23.59it/s]
#     box loss-> 0.02650, object loss-> 0.02473, class loss-> 0.00000
# Validation:
# 30it [00:04,  6.65it/s]
#     recall: 0.614286 precision: 0.661536 mAP@0.5: 0.606186, mAP@0.5-0.95: 0.221055
#
# Epoch 23/200
# ----------
# Train:
# 60it [00:02, 26.08it/s]
#     box loss-> 0.02814, object loss-> 0.02495, class loss-> 0.00000
# Validation:
# 30it [00:04,  6.18it/s]
#     recall: 0.571429 precision: 0.547846 mAP@0.5: 0.515367, mAP@0.5-0.95: 0.133087
#
# Epoch 24/200
# ----------
# Train:
# 60it [00:02, 25.56it/s]
#     box loss-> 0.02492, object loss-> 0.02383, class loss-> 0.00000
# Validation:
# 30it [00:04,  7.23it/s]
#     recall: 0.585714 precision: 0.706585 mAP@0.5: 0.602452, mAP@0.5-0.95: 0.201459
#
# Epoch 25/200
# ----------
# Train:
# 60it [00:02, 25.66it/s]
#     box loss-> 0.02209, object loss-> 0.02169, class loss-> 0.00000
# Validation:
# 30it [00:04,  6.43it/s]
#     recall: 0.500000 precision: 0.848204 mAP@0.5: 0.637118, mAP@0.5-0.95: 0.224804
#
# Epoch 26/200
# ----------
# Train:
# 60it [00:02, 25.78it/s]
#     box loss-> 0.02081, object loss-> 0.02065, class loss-> 0.00000
# Validation:
# 30it [00:03,  8.46it/s]
#     recall: 0.626823 precision: 0.516944 mAP@0.5: 0.553996, mAP@0.5-0.95: 0.110971
#
# Epoch 27/200
# ----------
# Train:
# 60it [00:02, 26.37it/s]
#     box loss-> 0.02495, object loss-> 0.02287, class loss-> 0.00000
# Validation:
# 30it [00:04,  6.82it/s]
#     recall: 0.514286 precision: 0.562044 mAP@0.5: 0.538798, mAP@0.5-0.95: 0.179784
#
# Epoch 28/200
# ----------
# Train:
# 60it [00:02, 25.52it/s]
#     box loss-> 0.02462, object loss-> 0.02240, class loss-> 0.00000
# Validation:
# 30it [00:03,  9.62it/s]
#     recall: 0.557001 precision: 0.534182 mAP@0.5: 0.551597, mAP@0.5-0.95: 0.131968
#
# Epoch 29/200
# ----------
# Train:
# 60it [00:02, 25.56it/s]
#     box loss-> 0.02209, object loss-> 0.02011, class loss-> 0.00000
# Validation:
# 30it [00:03,  7.93it/s]
#     recall: 0.642857 precision: 0.652136 mAP@0.5: 0.609441, mAP@0.5-0.95: 0.217651
#
# Epoch 30/200
# ----------
# Train:
# 60it [00:02, 23.44it/s]
#     box loss-> 0.02120, object loss-> 0.02043, class loss-> 0.00000
# Validation:
# 30it [00:03,  9.77it/s]
#     recall: 0.557143 precision: 0.706359 mAP@0.5: 0.597218, mAP@0.5-0.95: 0.214467
#
# Epoch 31/200
# ----------
# Train:
# 60it [00:02, 26.07it/s]
#     box loss-> 0.02165, object loss-> 0.02078, class loss-> 0.00000
# Validation:
# 30it [00:02, 10.26it/s]
#     recall: 0.657143 precision: 0.455398 mAP@0.5: 0.517475, mAP@0.5-0.95: 0.157653
#
# Epoch 32/200
# ----------
# Train:
# 60it [00:02, 20.05it/s]
#     box loss-> 0.02235, object loss-> 0.02005, class loss-> 0.00000
# Validation:
# 30it [00:02, 10.52it/s]
#     recall: 0.642857 precision: 0.702596 mAP@0.5: 0.660587, mAP@0.5-0.95: 0.227308
#
# Epoch 33/200
# ----------
# Train:
# 60it [00:02, 25.73it/s]
#     box loss-> 0.01792, object loss-> 0.01823, class loss-> 0.00000
# Validation:
# 30it [00:02, 11.93it/s]
#     recall: 0.571429 precision: 0.711734 mAP@0.5: 0.626719, mAP@0.5-0.95: 0.210455
#
# Epoch 34/200
# ----------
# Train:
# 60it [00:02, 25.06it/s]
#     box loss-> 0.02130, object loss-> 0.01978, class loss-> 0.00000
# Validation:
# 30it [00:03,  9.12it/s]
#     recall: 0.571429 precision: 0.674808 mAP@0.5: 0.619966, mAP@0.5-0.95: 0.226036
#
# Epoch 35/200
# ----------
# Train:
# 60it [00:02, 25.52it/s]
#     box loss-> 0.01796, object loss-> 0.01829, class loss-> 0.00000
# Validation:
# 30it [00:02, 12.54it/s]
#     recall: 0.585348 precision: 0.650649 mAP@0.5: 0.607881, mAP@0.5-0.95: 0.207026
#
# Epoch 36/200
# ----------
# Train:
# 60it [00:02, 25.82it/s]
#     box loss-> 0.01875, object loss-> 0.01786, class loss-> 0.00000
# Validation:
# 30it [00:02, 13.15it/s]
#     recall: 0.571429 precision: 0.713898 mAP@0.5: 0.645779, mAP@0.5-0.95: 0.200887
#
# Epoch 37/200
# ----------
# Train:
# 60it [00:03, 19.97it/s]
#     box loss-> 0.01654, object loss-> 0.01731, class loss-> 0.00000
# Validation:
# 30it [00:02, 13.25it/s]
#     recall: 0.571429 precision: 0.753321 mAP@0.5: 0.627215, mAP@0.5-0.95: 0.217540
#
# Epoch 38/200
# ----------
# Train:
# 60it [00:02, 26.15it/s]
#     box loss-> 0.01669, object loss-> 0.01684, class loss-> 0.00000
# Validation:
# 30it [00:02, 14.01it/s]
#     recall: 0.585714 precision: 0.628652 mAP@0.5: 0.611133, mAP@0.5-0.95: 0.211158
#
# Epoch 39/200
# ----------
# Train:
# 60it [00:02, 26.24it/s]
#     box loss-> 0.01829, object loss-> 0.01757, class loss-> 0.00000
# Validation:
# 30it [00:02, 12.21it/s]
#     recall: 0.571158 precision: 0.714187 mAP@0.5: 0.645327, mAP@0.5-0.95: 0.148812
#
# Epoch 40/200
# ----------
# Train:
# 60it [00:02, 21.99it/s]
#     box loss-> 0.01988, object loss-> 0.01862, class loss-> 0.00000
# Validation:
# 30it [00:02, 14.35it/s]
#     recall: 0.600000 precision: 0.723340 mAP@0.5: 0.634103, mAP@0.5-0.95: 0.236097
#
# Epoch 41/200
# ----------
# Train:
# 60it [00:02, 25.49it/s]
#     box loss-> 0.01814, object loss-> 0.01786, class loss-> 0.00000
# Validation:
# 30it [00:02, 14.99it/s]
#     recall: 0.542857 precision: 0.728356 mAP@0.5: 0.633437, mAP@0.5-0.95: 0.194265
#
# Epoch 42/200
# ----------
# Train:
# 60it [00:02, 25.88it/s]
#     box loss-> 0.01551, object loss-> 0.01642, class loss-> 0.00000
# Validation:
# 30it [00:02, 11.45it/s]
#     recall: 0.527277 precision: 0.803954 mAP@0.5: 0.655863, mAP@0.5-0.95: 0.196890
#
# Epoch 43/200
# ----------
# Train:
# 60it [00:02, 24.03it/s]
#     box loss-> 0.01903, object loss-> 0.01756, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.51it/s]
#     recall: 0.593673 precision: 0.709664 mAP@0.5: 0.631476, mAP@0.5-0.95: 0.232508
#
# Epoch 44/200
# ----------
# Train:
# 60it [00:02, 26.18it/s]
#     box loss-> 0.01789, object loss-> 0.01766, class loss-> 0.00000
# Validation:
# 30it [00:01, 16.03it/s]
#     recall: 0.585385 precision: 0.672005 mAP@0.5: 0.631998, mAP@0.5-0.95: 0.169882
#
# Epoch 45/200
# ----------
# Train:
# 60it [00:02, 24.87it/s]
#     box loss-> 0.01829, object loss-> 0.01782, class loss-> 0.00000
# Validation:
# 30it [00:02, 11.67it/s]
#     recall: 0.557128 precision: 0.764701 mAP@0.5: 0.631813, mAP@0.5-0.95: 0.240710
#
# Epoch 46/200
# ----------
# Train:
# 60it [00:02, 25.76it/s]
#     box loss-> 0.01467, object loss-> 0.01567, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.59it/s]
#     recall: 0.614286 precision: 0.671372 mAP@0.5: 0.648559, mAP@0.5-0.95: 0.205859
#
# Epoch 47/200
# ----------
# Train:
# 60it [00:02, 25.89it/s]
#     box loss-> 0.01461, object loss-> 0.01532, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.48it/s]
#     recall: 0.585714 precision: 0.609911 mAP@0.5: 0.618027, mAP@0.5-0.95: 0.234659
#
# Epoch 48/200
# ----------
# Train:
# 60it [00:02, 22.94it/s]
#     box loss-> 0.01514, object loss-> 0.01522, class loss-> 0.00000
# Validation:
# 30it [00:02, 12.79it/s]
#     recall: 0.557143 precision: 0.707990 mAP@0.5: 0.603312, mAP@0.5-0.95: 0.217017
#
# Epoch 49/200
# ----------
# Train:
# 60it [00:02, 25.64it/s]
#     box loss-> 0.01358, object loss-> 0.01435, class loss-> 0.00000
# Validation:
# 30it [00:01, 16.40it/s]
#     recall: 0.614286 precision: 0.660295 mAP@0.5: 0.621110, mAP@0.5-0.95: 0.225149
#
# Epoch 50/200
# ----------
# Train:
# 60it [00:02, 25.81it/s]
#     box loss-> 0.01434, object loss-> 0.01471, class loss-> 0.00000
# Validation:
# 30it [00:02, 13.05it/s]
#     recall: 0.614099 precision: 0.671807 mAP@0.5: 0.628688, mAP@0.5-0.95: 0.225876
#
# Epoch 51/200
# ----------
# Train:
# 60it [00:03, 19.83it/s]
#     box loss-> 0.01473, object loss-> 0.01448, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.12it/s]
#     recall: 0.571429 precision: 0.701338 mAP@0.5: 0.651042, mAP@0.5-0.95: 0.234136
#
# Epoch 52/200
# ----------
# Train:
# 60it [00:02, 24.76it/s]
#     box loss-> 0.01511, object loss-> 0.01469, class loss-> 0.00000
# Validation:
# 30it [00:01, 18.09it/s]
#     recall: 0.557143 precision: 0.721795 mAP@0.5: 0.638278, mAP@0.5-0.95: 0.237777
#
# Epoch 53/200
# ----------
# Train:
# 60it [00:02, 25.96it/s]
#     box loss-> 0.01468, object loss-> 0.01469, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.75it/s]
#     recall: 0.528571 precision: 0.696459 mAP@0.5: 0.622072, mAP@0.5-0.95: 0.199538
#
# Epoch 54/200
# ----------
# Train:
# 60it [00:02, 22.71it/s]
#     box loss-> 0.01497, object loss-> 0.01511, class loss-> 0.00000
# Validation:
# 30it [00:02, 14.99it/s]
#     recall: 0.485714 precision: 0.752066 mAP@0.5: 0.624192, mAP@0.5-0.95: 0.201572
#
# Epoch 55/200
# ----------
# Train:
# 60it [00:02, 25.68it/s]
#     box loss-> 0.01371, object loss-> 0.01426, class loss-> 0.00000
# Validation:
# 30it [00:01, 18.63it/s]
#     recall: 0.571429 precision: 0.664590 mAP@0.5: 0.611159, mAP@0.5-0.95: 0.223972
#
# Epoch 56/200
# ----------
# Train:
# 60it [00:02, 25.90it/s]
#     box loss-> 0.01368, object loss-> 0.01452, class loss-> 0.00000
# Validation:
# 30it [00:01, 18.74it/s]
#     recall: 0.600000 precision: 0.644998 mAP@0.5: 0.637321, mAP@0.5-0.95: 0.259711
#
# Epoch 57/200
# ----------
# Train:
# 60it [00:02, 23.95it/s]
#     box loss-> 0.01442, object loss-> 0.01506, class loss-> 0.00000
# Validation:
# 30it [00:02, 14.94it/s]
#     recall: 0.570750 precision: 0.644885 mAP@0.5: 0.599061, mAP@0.5-0.95: 0.210406
#
# Epoch 58/200
# ----------
# Train:
# 60it [00:02, 24.86it/s]
#     box loss-> 0.01310, object loss-> 0.01366, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.46it/s]
#     recall: 0.542822 precision: 0.730756 mAP@0.5: 0.616860, mAP@0.5-0.95: 0.236888
#
# Epoch 59/200
# ----------
# Train:
# 60it [00:02, 25.77it/s]
#     box loss-> 0.01295, object loss-> 0.01384, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.59it/s]
#     recall: 0.528571 precision: 0.802390 mAP@0.5: 0.657818, mAP@0.5-0.95: 0.245966
#
# Epoch 60/200
# ----------
# Train:
# 60it [00:02, 25.92it/s]
#     box loss-> 0.01395, object loss-> 0.01432, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.74it/s]
#     recall: 0.514286 precision: 0.799821 mAP@0.5: 0.652252, mAP@0.5-0.95: 0.208491
#
# Epoch 61/200
# ----------
# Train:
# 60it [00:02, 22.70it/s]
#     box loss-> 0.01473, object loss-> 0.01527, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.90it/s]
#     recall: 0.571429 precision: 0.676710 mAP@0.5: 0.603980, mAP@0.5-0.95: 0.228862
#
# Epoch 62/200
# ----------
# Train:
# 60it [00:02, 25.69it/s]
#     box loss-> 0.01127, object loss-> 0.01252, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.71it/s]
#     recall: 0.614286 precision: 0.631259 mAP@0.5: 0.622639, mAP@0.5-0.95: 0.218164
#
# Epoch 63/200
# ----------
# Train:
# 60it [00:02, 25.92it/s]
#     box loss-> 0.01431, object loss-> 0.01405, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.11it/s]
#     recall: 0.542857 precision: 0.775089 mAP@0.5: 0.635994, mAP@0.5-0.95: 0.265104
#
# Epoch 64/200
# ----------
# Train:
# 60it [00:02, 20.65it/s]
#     box loss-> 0.01494, object loss-> 0.01477, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.48it/s]
#     recall: 0.585714 precision: 0.671688 mAP@0.5: 0.628387, mAP@0.5-0.95: 0.232227
#
# Epoch 65/200
# ----------
# Train:
# 60it [00:02, 26.06it/s]
#     box loss-> 0.01162, object loss-> 0.01271, class loss-> 0.00000
# Validation:
# 30it [00:01, 18.62it/s]
#     recall: 0.614286 precision: 0.632690 mAP@0.5: 0.627087, mAP@0.5-0.95: 0.238723
#
# Epoch 66/200
# ----------
# Train:
# 60it [00:02, 25.38it/s]
#     box loss-> 0.01319, object loss-> 0.01380, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.93it/s]
#     recall: 0.613756 precision: 0.641590 mAP@0.5: 0.643639, mAP@0.5-0.95: 0.253792
#
# Epoch 67/200
# ----------
# Train:
# 60it [00:02, 20.57it/s]
#     box loss-> 0.01309, object loss-> 0.01334, class loss-> 0.00000
# Validation:
# 30it [00:01, 17.38it/s]
#     recall: 0.585018 precision: 0.640347 mAP@0.5: 0.621233, mAP@0.5-0.95: 0.201166
#
# Epoch 68/200
# ----------
# Train:
# 60it [00:02, 25.89it/s]
#     box loss-> 0.01392, object loss-> 0.01436, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.59it/s]
#     recall: 0.599739 precision: 0.711774 mAP@0.5: 0.626662, mAP@0.5-0.95: 0.241139
#
# Epoch 69/200
# ----------
# Train:
# 60it [00:02, 25.58it/s]
#     box loss-> 0.01228, object loss-> 0.01299, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.75it/s]
#     recall: 0.557143 precision: 0.637848 mAP@0.5: 0.623941, mAP@0.5-0.95: 0.238439
#
# Epoch 70/200
# ----------
# Train:
# 60it [00:02, 22.61it/s]
#     box loss-> 0.01109, object loss-> 0.01235, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.49it/s]
#     recall: 0.585170 precision: 0.620990 mAP@0.5: 0.618357, mAP@0.5-0.95: 0.248224
#
# Epoch 71/200
# ----------
# Train:
# 60it [00:02, 25.58it/s]
#     box loss-> 0.01235, object loss-> 0.01350, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.25it/s]
#     recall: 0.585714 precision: 0.650438 mAP@0.5: 0.637086, mAP@0.5-0.95: 0.231500
#
# Epoch 72/200
# ----------
# Train:
# 60it [00:02, 25.87it/s]
#     box loss-> 0.01319, object loss-> 0.01340, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.67it/s]
#     recall: 0.600000 precision: 0.625674 mAP@0.5: 0.620005, mAP@0.5-0.95: 0.245433
#
# Epoch 73/200
# ----------
# Train:
# 60it [00:02, 25.27it/s]
#     box loss-> 0.01114, object loss-> 0.01230, class loss-> 0.00000
# Validation:
# 30it [00:01, 15.76it/s]
#     recall: 0.585714 precision: 0.649690 mAP@0.5: 0.637698, mAP@0.5-0.95: 0.219337
#
# Epoch 74/200
# ----------
# Train:
# 60it [00:02, 23.15it/s]
#     box loss-> 0.01089, object loss-> 0.01191, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.45it/s]
#     recall: 0.614286 precision: 0.681783 mAP@0.5: 0.647750, mAP@0.5-0.95: 0.238313
#
# Epoch 75/200
# ----------
# Train:
# 60it [00:02, 25.93it/s]
#     box loss-> 0.01268, object loss-> 0.01303, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.36it/s]
#     recall: 0.584501 precision: 0.660819 mAP@0.5: 0.596985, mAP@0.5-0.95: 0.224027
#
# Epoch 76/200
# ----------
# Train:
# 60it [00:02, 26.02it/s]
#     box loss-> 0.01339, object loss-> 0.01336, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.70it/s]
#     recall: 0.571303 precision: 0.714240 mAP@0.5: 0.660229, mAP@0.5-0.95: 0.247330
#
# Epoch 77/200
# ----------
# Train:
# 60it [00:02, 20.19it/s]
#     box loss-> 0.01052, object loss-> 0.01158, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.64it/s]
#     recall: 0.585714 precision: 0.602224 mAP@0.5: 0.610218, mAP@0.5-0.95: 0.209022
#
# Epoch 78/200
# ----------
# Train:
# 60it [00:02, 25.86it/s]
#     box loss-> 0.01007, object loss-> 0.01140, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.07it/s]
#     recall: 0.598949 precision: 0.666271 mAP@0.5: 0.619790, mAP@0.5-0.95: 0.212366
#
# Epoch 79/200
# ----------
# Train:
# 60it [00:02, 25.90it/s]
#     box loss-> 0.01084, object loss-> 0.01158, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.96it/s]
#     recall: 0.571429 precision: 0.666048 mAP@0.5: 0.636124, mAP@0.5-0.95: 0.245476
#
# Epoch 80/200
# ----------
# Train:
# 60it [00:02, 21.72it/s]
#     box loss-> 0.01047, object loss-> 0.01150, class loss-> 0.00000
# Validation:
# 30it [00:01, 17.33it/s]
#     recall: 0.585714 precision: 0.659649 mAP@0.5: 0.618696, mAP@0.5-0.95: 0.237432
#
# Epoch 81/200
# ----------
# Train:
# 60it [00:02, 25.33it/s]
#     box loss-> 0.01037, object loss-> 0.01093, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.08it/s]
#     recall: 0.585714 precision: 0.630298 mAP@0.5: 0.618324, mAP@0.5-0.95: 0.239678
#
# Epoch 82/200
# ----------
# Train:
# 60it [00:02, 25.78it/s]
#     box loss-> 0.01023, object loss-> 0.01141, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.29it/s]
#     recall: 0.542279 precision: 0.703478 mAP@0.5: 0.638974, mAP@0.5-0.95: 0.251905
#
# Epoch 83/200
# ----------
# Train:
# 60it [00:02, 25.08it/s]
#     box loss-> 0.01106, object loss-> 0.01198, class loss-> 0.00000
# Validation:
# 30it [00:01, 17.22it/s]
#     recall: 0.600000 precision: 0.665206 mAP@0.5: 0.599441, mAP@0.5-0.95: 0.245468
#
# Epoch 84/200
# ----------
# Train:
# 60it [00:02, 22.74it/s]
#     box loss-> 0.01235, object loss-> 0.01295, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.61it/s]
#     recall: 0.557143 precision: 0.671783 mAP@0.5: 0.616663, mAP@0.5-0.95: 0.251567
#
# Epoch 85/200
# ----------
# Train:
# 60it [00:02, 25.85it/s]
#     box loss-> 0.01176, object loss-> 0.01271, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.74it/s]
#     recall: 0.614253 precision: 0.614273 mAP@0.5: 0.613907, mAP@0.5-0.95: 0.248186
#
# Epoch 86/200
# ----------
# Train:
# 60it [00:02, 25.72it/s]
#     box loss-> 0.01055, object loss-> 0.01185, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.79it/s]
#     recall: 0.614286 precision: 0.613608 mAP@0.5: 0.628069, mAP@0.5-0.95: 0.230482
#
# Epoch 87/200
# ----------
# Train:
# 60it [00:02, 20.29it/s]
#     box loss-> 0.01063, object loss-> 0.01160, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.59it/s]
#     recall: 0.613396 precision: 0.622843 mAP@0.5: 0.615446, mAP@0.5-0.95: 0.236962
#
# Epoch 88/200
# ----------
# Train:
# 60it [00:02, 25.40it/s]
#     box loss-> 0.01100, object loss-> 0.01200, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.57it/s]
#     recall: 0.585022 precision: 0.602654 mAP@0.5: 0.614933, mAP@0.5-0.95: 0.209426
#
# Epoch 89/200
# ----------
# Train:
# 60it [00:02, 25.45it/s]
#     box loss-> 0.01029, object loss-> 0.01179, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.44it/s]
#     recall: 0.598701 precision: 0.655754 mAP@0.5: 0.604694, mAP@0.5-0.95: 0.236321
#
# Epoch 90/200
# ----------
# Train:
# 60it [00:02, 23.72it/s]
#     box loss-> 0.00929, object loss-> 0.01087, class loss-> 0.00000
# Validation:
# 30it [00:01, 16.79it/s]
#     recall: 0.585714 precision: 0.630595 mAP@0.5: 0.596915, mAP@0.5-0.95: 0.228805
#
# Epoch 91/200
# ----------
# Train:
# 60it [00:02, 25.16it/s]
#     box loss-> 0.01088, object loss-> 0.01161, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.55it/s]
#     recall: 0.571429 precision: 0.592890 mAP@0.5: 0.606478, mAP@0.5-0.95: 0.213441
#
# Epoch 92/200
# ----------
# Train:
# 60it [00:02, 25.92it/s]
#     box loss-> 0.01143, object loss-> 0.01211, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.70it/s]
#     recall: 0.571429 precision: 0.654566 mAP@0.5: 0.597176, mAP@0.5-0.95: 0.224576
#
# Epoch 93/200
# ----------
# Train:
# 60it [00:02, 25.85it/s]
#     box loss-> 0.01050, object loss-> 0.01181, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.08it/s]
#     recall: 0.600000 precision: 0.615944 mAP@0.5: 0.609787, mAP@0.5-0.95: 0.234565
#
# Epoch 94/200
# ----------
# Train:
# 60it [00:02, 21.05it/s]
#     box loss-> 0.01018, object loss-> 0.01114, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.21it/s]
#     recall: 0.571429 precision: 0.701384 mAP@0.5: 0.638520, mAP@0.5-0.95: 0.218396
#
# Epoch 95/200
# ----------
# Train:
# 60it [00:02, 26.08it/s]
#     box loss-> 0.00956, object loss-> 0.01109, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.88it/s]
#     recall: 0.613745 precision: 0.641586 mAP@0.5: 0.618306, mAP@0.5-0.95: 0.251032
#
# Epoch 96/200
# ----------
# Train:
# 60it [00:02, 26.04it/s]
#     box loss-> 0.01038, object loss-> 0.01168, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.33it/s]
#     recall: 0.556380 precision: 0.735578 mAP@0.5: 0.622273, mAP@0.5-0.95: 0.221420
#
# Epoch 97/200
# ----------
# Train:
# 60it [00:02, 22.68it/s]
#     box loss-> 0.01052, object loss-> 0.01183, class loss-> 0.00000
# Validation:
# 30it [00:01, 18.00it/s]
#     recall: 0.570978 precision: 0.624812 mAP@0.5: 0.608945, mAP@0.5-0.95: 0.253356
#
# Epoch 98/200
# ----------
# Train:
# 60it [00:02, 25.65it/s]
#     box loss-> 0.00845, object loss-> 0.01026, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.58it/s]
#     recall: 0.600000 precision: 0.616559 mAP@0.5: 0.615115, mAP@0.5-0.95: 0.239081
#
# Epoch 99/200
# ----------
# Train:
# 60it [00:02, 25.85it/s]
#     box loss-> 0.00940, object loss-> 0.01090, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.52it/s]
#     recall: 0.614286 precision: 0.622011 mAP@0.5: 0.615458, mAP@0.5-0.95: 0.238346
#
# Epoch 100/200
# ----------
# Train:
# 60it [00:02, 25.85it/s]
#     box loss-> 0.01039, object loss-> 0.01102, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.08it/s]
#     recall: 0.571429 precision: 0.643924 mAP@0.5: 0.629964, mAP@0.5-0.95: 0.241714
#
# Epoch 101/200
# ----------
# Train:
# 60it [00:02, 20.95it/s]
#     box loss-> 0.00887, object loss-> 0.01025, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.76it/s]
#     recall: 0.600000 precision: 0.608517 mAP@0.5: 0.599180, mAP@0.5-0.95: 0.235434
#
# Epoch 102/200
# ----------
# Train:
# 60it [00:02, 26.15it/s]
#     box loss-> 0.00826, object loss-> 0.00983, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.34it/s]
#     recall: 0.528571 precision: 0.696351 mAP@0.5: 0.611004, mAP@0.5-0.95: 0.239616
#
# Epoch 103/200
# ----------
# Train:
# 60it [00:02, 26.06it/s]
#     box loss-> 0.00813, object loss-> 0.00960, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.24it/s]
#     recall: 0.600000 precision: 0.636140 mAP@0.5: 0.630694, mAP@0.5-0.95: 0.254704
#
# Epoch 104/200
# ----------
# Train:
# 60it [00:02, 22.13it/s]
#     box loss-> 0.00836, object loss-> 0.00972, class loss-> 0.00000
# Validation:
# 30it [00:01, 19.07it/s]
#     recall: 0.600000 precision: 0.666281 mAP@0.5: 0.652924, mAP@0.5-0.95: 0.261404
#
# Epoch 105/200
# ----------
# Train:
# 60it [00:02, 25.98it/s]
#     box loss-> 0.00851, object loss-> 0.01020, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.25it/s]
#     recall: 0.527737 precision: 0.684838 mAP@0.5: 0.628672, mAP@0.5-0.95: 0.243244
#
# Epoch 106/200
# ----------
# Train:
# 60it [00:02, 26.19it/s]
#     box loss-> 0.00793, object loss-> 0.00956, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.84it/s]
#     recall: 0.556625 precision: 0.684006 mAP@0.5: 0.635707, mAP@0.5-0.95: 0.229775
#
# Epoch 107/200
# ----------
# Train:
# 60it [00:02, 25.83it/s]
#     box loss-> 0.00856, object loss-> 0.01020, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.08it/s]
#     recall: 0.585714 precision: 0.640008 mAP@0.5: 0.635633, mAP@0.5-0.95: 0.258019
#
# Epoch 108/200
# ----------
# Train:
# 60it [00:02, 21.22it/s]
#     box loss-> 0.00904, object loss-> 0.01092, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.00it/s]
#     recall: 0.571429 precision: 0.623675 mAP@0.5: 0.602683, mAP@0.5-0.95: 0.221064
#
# Epoch 109/200
# ----------
# Train:
# 60it [00:02, 25.63it/s]
#     box loss-> 0.00802, object loss-> 0.00982, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.02it/s]
#     recall: 0.584698 precision: 0.650393 mAP@0.5: 0.645432, mAP@0.5-0.95: 0.251746
#
# Epoch 110/200
# ----------
# Train:
# 60it [00:02, 25.83it/s]
#     box loss-> 0.00790, object loss-> 0.00963, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.45it/s]
#     recall: 0.600000 precision: 0.625271 mAP@0.5: 0.634867, mAP@0.5-0.95: 0.251722
#
# Epoch 111/200
# ----------
# Train:
# 60it [00:02, 22.42it/s]
#     box loss-> 0.00944, object loss-> 0.01079, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.07it/s]
#     recall: 0.498528 precision: 0.853281 mAP@0.5: 0.667913, mAP@0.5-0.95: 0.239342
#
# Epoch 112/200
# ----------
# Train:
# 60it [00:02, 25.81it/s]
#     box loss-> 0.00897, object loss-> 0.01029, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.97it/s]
#     recall: 0.584734 precision: 0.650407 mAP@0.5: 0.627034, mAP@0.5-0.95: 0.236882
#
# Epoch 113/200
# ----------
# Train:
# 60it [00:02, 25.95it/s]
#     box loss-> 0.00750, object loss-> 0.00945, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.36it/s]
#     recall: 0.571429 precision: 0.605484 mAP@0.5: 0.589083, mAP@0.5-0.95: 0.217984
#
# Epoch 114/200
# ----------
# Train:
# 60it [00:02, 25.88it/s]
#     box loss-> 0.00797, object loss-> 0.00950, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.99it/s]
#     recall: 0.571429 precision: 0.624516 mAP@0.5: 0.622776, mAP@0.5-0.95: 0.238890
#
# Epoch 115/200
# ----------
# Train:
# 60it [00:02, 20.87it/s]
#     box loss-> 0.00871, object loss-> 0.00993, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.56it/s]
#     recall: 0.542803 precision: 0.716961 mAP@0.5: 0.646123, mAP@0.5-0.95: 0.264983
#
# Epoch 116/200
# ----------
# Train:
# 60it [00:02, 25.91it/s]
#     box loss-> 0.00820, object loss-> 0.01001, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.89it/s]
#     recall: 0.571429 precision: 0.634147 mAP@0.5: 0.606948, mAP@0.5-0.95: 0.238215
#
# Epoch 117/200
# ----------
# Train:
# 60it [00:02, 25.26it/s]
#     box loss-> 0.00729, object loss-> 0.00894, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.48it/s]
#     recall: 0.585714 precision: 0.640519 mAP@0.5: 0.648082, mAP@0.5-0.95: 0.255354
#
# Epoch 118/200
# ----------
# Train:
# 60it [00:02, 22.08it/s]
#     box loss-> 0.00803, object loss-> 0.00975, class loss-> 0.00000
# Validation:
# 30it [00:01, 18.90it/s]
#     recall: 0.600000 precision: 0.617269 mAP@0.5: 0.620110, mAP@0.5-0.95: 0.224528
#
# Epoch 119/200
# ----------
# Train:
# 60it [00:02, 25.58it/s]
#     box loss-> 0.00808, object loss-> 0.00968, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.11it/s]
#     recall: 0.540634 precision: 0.729948 mAP@0.5: 0.633472, mAP@0.5-0.95: 0.238341
#
# Epoch 120/200
# ----------
# Train:
# 60it [00:02, 25.54it/s]
#     box loss-> 0.00781, object loss-> 0.00925, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.48it/s]
#     recall: 0.585714 precision: 0.681255 mAP@0.5: 0.641092, mAP@0.5-0.95: 0.243978
#
# Epoch 121/200
# ----------
# Train:
# 60it [00:02, 25.72it/s]
#     box loss-> 0.00710, object loss-> 0.00871, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.32it/s]
#     recall: 0.585714 precision: 0.630424 mAP@0.5: 0.614805, mAP@0.5-0.95: 0.242479
#
# Epoch 122/200
# ----------
# Train:
# 60it [00:02, 20.31it/s]
#     box loss-> 0.00767, object loss-> 0.00924, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.01it/s]
#     recall: 0.613568 precision: 0.632077 mAP@0.5: 0.633177, mAP@0.5-0.95: 0.241577
#
# Epoch 123/200
# ----------
# Train:
# 60it [00:02, 26.06it/s]
#     box loss-> 0.00701, object loss-> 0.00861, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.16it/s]
#     recall: 0.614286 precision: 0.622874 mAP@0.5: 0.641645, mAP@0.5-0.95: 0.244766
#
# Epoch 124/200
# ----------
# Train:
# 60it [00:02, 25.44it/s]
#     box loss-> 0.00670, object loss-> 0.00837, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.98it/s]
#     recall: 0.600000 precision: 0.646120 mAP@0.5: 0.625312, mAP@0.5-0.95: 0.239998
#
# Epoch 125/200
# ----------
# Train:
# 60it [00:02, 22.67it/s]
#     box loss-> 0.00664, object loss-> 0.00827, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.17it/s]
#     recall: 0.614286 precision: 0.641261 mAP@0.5: 0.642203, mAP@0.5-0.95: 0.245593
#
# Epoch 126/200
# ----------
# Train:
# 60it [00:02, 24.53it/s]
#     box loss-> 0.00673, object loss-> 0.00844, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.76it/s]
#     recall: 0.614286 precision: 0.631993 mAP@0.5: 0.644716, mAP@0.5-0.95: 0.241087
#
# Epoch 127/200
# ----------
# Train:
# 60it [00:02, 26.16it/s]
#     box loss-> 0.00734, object loss-> 0.00905, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.83it/s]
#     recall: 0.584976 precision: 0.640330 mAP@0.5: 0.622541, mAP@0.5-0.95: 0.239360
#
# Epoch 128/200
# ----------
# Train:
# 60it [00:02, 25.67it/s]
#     box loss-> 0.00761, object loss-> 0.00920, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.65it/s]
#     recall: 0.600000 precision: 0.616964 mAP@0.5: 0.615104, mAP@0.5-0.95: 0.244203
#
# Epoch 129/200
# ----------
# Train:
# 60it [00:02, 20.47it/s]
#     box loss-> 0.00657, object loss-> 0.00823, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.24it/s]
#     recall: 0.600000 precision: 0.614512 mAP@0.5: 0.616064, mAP@0.5-0.95: 0.247549
#
# Epoch 130/200
# ----------
# Train:
# 60it [00:02, 25.47it/s]
#     box loss-> 0.00667, object loss-> 0.00826, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.68it/s]
#     recall: 0.585714 precision: 0.611922 mAP@0.5: 0.616482, mAP@0.5-0.95: 0.244698
#
# Epoch 131/200
# ----------
# Train:
# 60it [00:02, 25.55it/s]
#     box loss-> 0.00673, object loss-> 0.00831, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.59it/s]
#     recall: 0.585019 precision: 0.640347 mAP@0.5: 0.633482, mAP@0.5-0.95: 0.253276
#
# Epoch 132/200
# ----------
# Train:
# 60it [00:02, 23.72it/s]
#     box loss-> 0.00699, object loss-> 0.00867, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.44it/s]
#     recall: 0.585714 precision: 0.602657 mAP@0.5: 0.612381, mAP@0.5-0.95: 0.239354
#
# Epoch 133/200
# ----------
# Train:
# 60it [00:02, 22.96it/s]
#     box loss-> 0.00720, object loss-> 0.00858, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.95it/s]
#     recall: 0.557143 precision: 0.647623 mAP@0.5: 0.611171, mAP@0.5-0.95: 0.249575
#
# Epoch 134/200
# ----------
# Train:
# 60it [00:02, 25.82it/s]
#     box loss-> 0.00643, object loss-> 0.00809, class loss-> 0.00000
# Validation:
# 30it [00:01, 24.44it/s]
#     recall: 0.585714 precision: 0.630450 mAP@0.5: 0.621046, mAP@0.5-0.95: 0.241979
#
# Epoch 135/200
# ----------
# Train:
# 60it [00:03, 19.77it/s]
#     box loss-> 0.00704, object loss-> 0.00898, class loss-> 0.00000
# Validation:
# 30it [00:01, 23.05it/s]
#     recall: 0.571429 precision: 0.615110 mAP@0.5: 0.599457, mAP@0.5-0.95: 0.229796
#
# Epoch 136/200
# ----------
# Train:
# 60it [00:02, 20.17it/s]
#     box loss-> 0.00709, object loss-> 0.00878, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.08it/s]
#     recall: 0.600000 precision: 0.625718 mAP@0.5: 0.614253, mAP@0.5-0.95: 0.249568
#
# Epoch 137/200
# ----------
# Train:
# 60it [00:02, 25.34it/s]
#     box loss-> 0.00649, object loss-> 0.00818, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.61it/s]
#     recall: 0.614286 precision: 0.614139 mAP@0.5: 0.621011, mAP@0.5-0.95: 0.262929
#
# Epoch 138/200
# ----------
# Train:
# 60it [00:02, 24.91it/s]
#     box loss-> 0.00636, object loss-> 0.00781, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.12it/s]
#     recall: 0.585714 precision: 0.630265 mAP@0.5: 0.624201, mAP@0.5-0.95: 0.252260
#
# Epoch 139/200
# ----------
# Train:
# 60it [00:02, 22.30it/s]
#     box loss-> 0.00617, object loss-> 0.00770, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.49it/s]
#     recall: 0.599792 precision: 0.608612 mAP@0.5: 0.624563, mAP@0.5-0.95: 0.236708
#
# Epoch 140/200
# ----------
# Train:
# 60it [00:02, 24.66it/s]
#     box loss-> 0.00651, object loss-> 0.00798, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.92it/s]
#     recall: 0.585714 precision: 0.650707 mAP@0.5: 0.632556, mAP@0.5-0.95: 0.250539
#
# Epoch 141/200
# ----------
# Train:
# 60it [00:02, 25.24it/s]
#     box loss-> 0.00633, object loss-> 0.00777, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.17it/s]
#     recall: 0.584928 precision: 0.640311 mAP@0.5: 0.637182, mAP@0.5-0.95: 0.256395
#
# Epoch 142/200
# ----------
# Train:
# 60it [00:02, 25.57it/s]
#     box loss-> 0.00584, object loss-> 0.00745, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.40it/s]
#     recall: 0.542857 precision: 0.702612 mAP@0.5: 0.633977, mAP@0.5-0.95: 0.258294
#
# Epoch 143/200
# ----------
# Train:
# 60it [00:02, 20.67it/s]
#     box loss-> 0.00628, object loss-> 0.00791, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.02it/s]
#     recall: 0.542857 precision: 0.665282 mAP@0.5: 0.625308, mAP@0.5-0.95: 0.240477
#
# Epoch 144/200
# ----------
# Train:
# 60it [00:02, 25.42it/s]
#     box loss-> 0.00610, object loss-> 0.00770, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.18it/s]
#     recall: 0.600000 precision: 0.608147 mAP@0.5: 0.623768, mAP@0.5-0.95: 0.239262
#
# Epoch 145/200
# ----------
# Train:
# 60it [00:02, 25.44it/s]
#     box loss-> 0.00638, object loss-> 0.00800, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.97it/s]
#     recall: 0.598807 precision: 0.645692 mAP@0.5: 0.622987, mAP@0.5-0.95: 0.247490
#
# Epoch 146/200
# ----------
# Train:
# 60it [00:02, 23.44it/s]
#     box loss-> 0.00598, object loss-> 0.00759, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.75it/s]
#     recall: 0.599071 precision: 0.626498 mAP@0.5: 0.625413, mAP@0.5-0.95: 0.233065
#
# Epoch 147/200
# ----------
# Train:
# 60it [00:02, 23.42it/s]
#     box loss-> 0.00591, object loss-> 0.00776, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.72it/s]
#     recall: 0.542857 precision: 0.688253 mAP@0.5: 0.638181, mAP@0.5-0.95: 0.242171
#
# Epoch 148/200
# ----------
# Train:
# 60it [00:02, 24.90it/s]
#     box loss-> 0.00643, object loss-> 0.00827, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.97it/s]
#     recall: 0.557143 precision: 0.658859 mAP@0.5: 0.618891, mAP@0.5-0.95: 0.233862
#
# Epoch 149/200
# ----------
# Train:
# 60it [00:02, 25.14it/s]
#     box loss-> 0.00574, object loss-> 0.00745, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.15it/s]
#     recall: 0.585714 precision: 0.639940 mAP@0.5: 0.629862, mAP@0.5-0.95: 0.236586
#
# Epoch 150/200
# ----------
# Train:
# 60it [00:02, 20.23it/s]
#     box loss-> 0.00573, object loss-> 0.00728, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.89it/s]
#     recall: 0.600000 precision: 0.597622 mAP@0.5: 0.604436, mAP@0.5-0.95: 0.229404
#
# Epoch 151/200
# ----------
# Train:
# 60it [00:02, 25.81it/s]
#     box loss-> 0.00576, object loss-> 0.00745, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.28it/s]
#     recall: 0.614286 precision: 0.650674 mAP@0.5: 0.645734, mAP@0.5-0.95: 0.245335
#
# Epoch 152/200
# ----------
# Train:
# 60it [00:02, 26.05it/s]
#     box loss-> 0.00590, object loss-> 0.00756, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.34it/s]
#     recall: 0.614286 precision: 0.632301 mAP@0.5: 0.644114, mAP@0.5-0.95: 0.241097
#
# Epoch 153/200
# ----------
# Train:
# 60it [00:02, 25.66it/s]
#     box loss-> 0.00567, object loss-> 0.00729, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.39it/s]
#     recall: 0.614281 precision: 0.623186 mAP@0.5: 0.641055, mAP@0.5-0.95: 0.247675
#
# Epoch 154/200
# ----------
# Train:
# 60it [00:02, 21.20it/s]
#     box loss-> 0.00544, object loss-> 0.00713, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.29it/s]
#     recall: 0.600000 precision: 0.591533 mAP@0.5: 0.604586, mAP@0.5-0.95: 0.247633
#
# Epoch 155/200
# ----------
# Train:
# 60it [00:02, 26.14it/s]
#     box loss-> 0.00542, object loss-> 0.00701, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.58it/s]
#     recall: 0.614286 precision: 0.604849 mAP@0.5: 0.634535, mAP@0.5-0.95: 0.241320
#
# Epoch 156/200
# ----------
# Train:
# 60it [00:02, 26.10it/s]
#     box loss-> 0.00543, object loss-> 0.00716, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.11it/s]
#     recall: 0.614286 precision: 0.612344 mAP@0.5: 0.644480, mAP@0.5-0.95: 0.255156
#
# Epoch 157/200
# ----------
# Train:
# 60it [00:02, 22.62it/s]
#     box loss-> 0.00543, object loss-> 0.00706, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.59it/s]
#     recall: 0.599800 precision: 0.646076 mAP@0.5: 0.641073, mAP@0.5-0.95: 0.248153
#
# Epoch 158/200
# ----------
# Train:
# 60it [00:02, 24.35it/s]
#     box loss-> 0.00536, object loss-> 0.00689, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.52it/s]
#     recall: 0.600000 precision: 0.626750 mAP@0.5: 0.631555, mAP@0.5-0.95: 0.245696
#
# Epoch 159/200
# ----------
# Train:
# 60it [00:02, 25.88it/s]
#     box loss-> 0.00547, object loss-> 0.00703, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.85it/s]
#     recall: 0.599428 precision: 0.636140 mAP@0.5: 0.637795, mAP@0.5-0.95: 0.245284
#
# Epoch 160/200
# ----------
# Train:
# 60it [00:02, 25.90it/s]
#     box loss-> 0.00548, object loss-> 0.00697, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.41it/s]
#     recall: 0.600000 precision: 0.626235 mAP@0.5: 0.621611, mAP@0.5-0.95: 0.242459
#
# Epoch 161/200
# ----------
# Train:
# 60it [00:02, 20.14it/s]
#     box loss-> 0.00538, object loss-> 0.00699, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.38it/s]
#     recall: 0.613945 precision: 0.641662 mAP@0.5: 0.634560, mAP@0.5-0.95: 0.247059
#
# Epoch 162/200
# ----------
# Train:
# 60it [00:02, 25.89it/s]
#     box loss-> 0.00536, object loss-> 0.00703, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.57it/s]
#     recall: 0.600000 precision: 0.636076 mAP@0.5: 0.634721, mAP@0.5-0.95: 0.250146
#
# Epoch 163/200
# ----------
# Train:
# 60it [00:02, 26.22it/s]
#     box loss-> 0.00547, object loss-> 0.00702, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.11it/s]
#     recall: 0.600000 precision: 0.625216 mAP@0.5: 0.647571, mAP@0.5-0.95: 0.252803
#
# Epoch 164/200
# ----------
# Train:
# 60it [00:02, 26.01it/s]
#     box loss-> 0.00548, object loss-> 0.00705, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.29it/s]
#     recall: 0.557143 precision: 0.683833 mAP@0.5: 0.636326, mAP@0.5-0.95: 0.252470
#
# Epoch 165/200
# ----------
# Train:
# 60it [00:02, 21.55it/s]
#     box loss-> 0.00515, object loss-> 0.00674, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.11it/s]
#     recall: 0.599345 precision: 0.636107 mAP@0.5: 0.634182, mAP@0.5-0.95: 0.244716
#
# Epoch 166/200
# ----------
# Train:
# 60it [00:02, 26.11it/s]
#     box loss-> 0.00537, object loss-> 0.00694, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.02it/s]
#     recall: 0.585714 precision: 0.621124 mAP@0.5: 0.625251, mAP@0.5-0.95: 0.242231
#
# Epoch 167/200
# ----------
# Train:
# 60it [00:02, 25.98it/s]
#     box loss-> 0.00525, object loss-> 0.00675, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.34it/s]
#     recall: 0.614286 precision: 0.650802 mAP@0.5: 0.646643, mAP@0.5-0.95: 0.252757
#
# Epoch 168/200
# ----------
# Train:
# 60it [00:02, 22.07it/s]
#     box loss-> 0.00535, object loss-> 0.00685, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.13it/s]
#     recall: 0.600000 precision: 0.635942 mAP@0.5: 0.638278, mAP@0.5-0.95: 0.252576
#
# Epoch 169/200
# ----------
# Train:
# 60it [00:02, 25.60it/s]
#     box loss-> 0.00522, object loss-> 0.00675, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.55it/s]
#     recall: 0.614286 precision: 0.596096 mAP@0.5: 0.608283, mAP@0.5-0.95: 0.246075
#
# Epoch 170/200
# ----------
# Train:
# 60it [00:02, 25.74it/s]
#     box loss-> 0.00532, object loss-> 0.00690, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.45it/s]
#     recall: 0.600000 precision: 0.636153 mAP@0.5: 0.628934, mAP@0.5-0.95: 0.255192
#
# Epoch 171/200
# ----------
# Train:
# 60it [00:02, 25.74it/s]
#     box loss-> 0.00517, object loss-> 0.00675, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.43it/s]
#     recall: 0.571429 precision: 0.645148 mAP@0.5: 0.643678, mAP@0.5-0.95: 0.253997
#
# Epoch 172/200
# ----------
# Train:
# 60it [00:02, 20.03it/s]
#     box loss-> 0.00510, object loss-> 0.00663, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.36it/s]
#     recall: 0.595959 precision: 0.616033 mAP@0.5: 0.635547, mAP@0.5-0.95: 0.255449
#
# Epoch 173/200
# ----------
# Train:
# 60it [00:02, 26.03it/s]
#     box loss-> 0.00504, object loss-> 0.00659, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.34it/s]
#     recall: 0.598739 precision: 0.626367 mAP@0.5: 0.639060, mAP@0.5-0.95: 0.256852
#
# Epoch 174/200
# ----------
# Train:
# 60it [00:02, 25.60it/s]
#     box loss-> 0.00511, object loss-> 0.00682, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.23it/s]
#     recall: 0.614286 precision: 0.613622 mAP@0.5: 0.645785, mAP@0.5-0.95: 0.253864
#
# Epoch 175/200
# ----------
# Train:
# 60it [00:02, 24.80it/s]
#     box loss-> 0.00500, object loss-> 0.00651, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.05it/s]
#     recall: 0.585714 precision: 0.640590 mAP@0.5: 0.638723, mAP@0.5-0.95: 0.253458
#
# Epoch 176/200
# ----------
# Train:
# 60it [00:02, 21.98it/s]
#     box loss-> 0.00512, object loss-> 0.00669, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.31it/s]
#     recall: 0.571429 precision: 0.644555 mAP@0.5: 0.625581, mAP@0.5-0.95: 0.251162
#
# Epoch 177/200
# ----------
# Train:
# 60it [00:02, 25.77it/s]
#     box loss-> 0.00498, object loss-> 0.00658, class loss-> 0.00000
# Validation:
# 30it [00:01, 27.93it/s]
#     recall: 0.585337 precision: 0.640474 mAP@0.5: 0.630724, mAP@0.5-0.95: 0.249021
#
# Epoch 178/200
# ----------
# Train:
# 60it [00:02, 25.80it/s]
#     box loss-> 0.00492, object loss-> 0.00654, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.83it/s]
#     recall: 0.585714 precision: 0.610316 mAP@0.5: 0.628923, mAP@0.5-0.95: 0.243320
#
# Epoch 179/200
# ----------
# Train:
# 60it [00:02, 22.00it/s]
#     box loss-> 0.00490, object loss-> 0.00645, class loss-> 0.00000
# Validation:
# 30it [00:01, 20.81it/s]
#     recall: 0.571429 precision: 0.641989 mAP@0.5: 0.631149, mAP@0.5-0.95: 0.248706
#
# Epoch 180/200
# ----------
# Train:
# 60it [00:02, 25.35it/s]
#     box loss-> 0.00493, object loss-> 0.00639, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.63it/s]
#     recall: 0.614286 precision: 0.621326 mAP@0.5: 0.637882, mAP@0.5-0.95: 0.246830
#
# Epoch 181/200
# ----------
# Train:
# 60it [00:02, 25.53it/s]
#     box loss-> 0.00495, object loss-> 0.00648, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.80it/s]
#     recall: 0.585714 precision: 0.630543 mAP@0.5: 0.634337, mAP@0.5-0.95: 0.247307
#
# Epoch 182/200
# ----------
# Train:
# 60it [00:02, 25.40it/s]
#     box loss-> 0.00495, object loss-> 0.00637, class loss-> 0.00000
# Validation:
# 30it [00:01, 26.13it/s]
#     recall: 0.600000 precision: 0.655074 mAP@0.5: 0.633491, mAP@0.5-0.95: 0.245923
#
# Epoch 183/200
# ----------
# Train:
# 60it [00:03, 19.89it/s]
#     box loss-> 0.00474, object loss-> 0.00632, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.78it/s]
#     recall: 0.600000 precision: 0.617193 mAP@0.5: 0.625074, mAP@0.5-0.95: 0.246634
#
# Epoch 184/200
# ----------
# Train:
# 60it [00:02, 25.82it/s]
#     box loss-> 0.00483, object loss-> 0.00638, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.71it/s]
#     recall: 0.585003 precision: 0.630482 mAP@0.5: 0.623970, mAP@0.5-0.95: 0.247834
#
# Epoch 185/200
# ----------
# Train:
# 60it [00:02, 25.88it/s]
#     box loss-> 0.00468, object loss-> 0.00625, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.88it/s]
#     recall: 0.614009 precision: 0.632247 mAP@0.5: 0.635433, mAP@0.5-0.95: 0.248067
#
# Epoch 186/200
# ----------
# Train:
# 60it [00:02, 24.65it/s]
#     box loss-> 0.00485, object loss-> 0.00642, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.92it/s]
#     recall: 0.614240 precision: 0.632335 mAP@0.5: 0.642310, mAP@0.5-0.95: 0.250164
#
# Epoch 187/200
# ----------
# Train:
# 60it [00:02, 22.29it/s]
#     box loss-> 0.00474, object loss-> 0.00629, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.48it/s]
#     recall: 0.614286 precision: 0.632260 mAP@0.5: 0.646511, mAP@0.5-0.95: 0.261890
#
# Epoch 188/200
# ----------
# Train:
# 60it [00:02, 25.95it/s]
#     box loss-> 0.00488, object loss-> 0.00644, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.08it/s]
#     recall: 0.614286 precision: 0.631899 mAP@0.5: 0.634365, mAP@0.5-0.95: 0.254390
#
# Epoch 189/200
# ----------
# Train:
# 60it [00:02, 25.88it/s]
#     box loss-> 0.00473, object loss-> 0.00625, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.75it/s]
#     recall: 0.600000 precision: 0.626364 mAP@0.5: 0.638745, mAP@0.5-0.95: 0.256280
#
# Epoch 190/200
# ----------
# Train:
# 60it [00:02, 22.43it/s]
#     box loss-> 0.00471, object loss-> 0.00628, class loss-> 0.00000
# Validation:
# 30it [00:01, 22.05it/s]
#     recall: 0.585714 precision: 0.650148 mAP@0.5: 0.623403, mAP@0.5-0.95: 0.250890
#
# Epoch 191/200
# ----------
# Train:
# 60it [00:02, 24.51it/s]
#     box loss-> 0.00479, object loss-> 0.00638, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.91it/s]
#     recall: 0.585714 precision: 0.640245 mAP@0.5: 0.640779, mAP@0.5-0.95: 0.250634
#
# Epoch 192/200
# ----------
# Train:
# 60it [00:02, 25.34it/s]
#     box loss-> 0.00474, object loss-> 0.00634, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.91it/s]
#     recall: 0.570556 precision: 0.644806 mAP@0.5: 0.632427, mAP@0.5-0.95: 0.247113
#
# Epoch 193/200
# ----------
# Train:
# 60it [00:02, 25.78it/s]
#     box loss-> 0.00473, object loss-> 0.00625, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.38it/s]
#     recall: 0.585443 precision: 0.650687 mAP@0.5: 0.631990, mAP@0.5-0.95: 0.251771
#
# Epoch 194/200
# ----------
# Train:
# 60it [00:03, 19.99it/s]
#     box loss-> 0.00470, object loss-> 0.00626, class loss-> 0.00000
# Validation:
# 30it [00:01, 25.53it/s]
#     recall: 0.585173 precision: 0.640409 mAP@0.5: 0.640255, mAP@0.5-0.95: 0.254055
#
# Epoch 195/200
# ----------
# Train:
# 60it [00:02, 25.46it/s]
#     box loss-> 0.00465, object loss-> 0.00626, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.54it/s]
#     recall: 0.557143 precision: 0.672225 mAP@0.5: 0.639093, mAP@0.5-0.95: 0.251333
#
# Epoch 196/200
# ----------
# Train:
# 60it [00:02, 25.89it/s]
#     box loss-> 0.00457, object loss-> 0.00609, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.35it/s]
#     recall: 0.600000 precision: 0.617403 mAP@0.5: 0.636004, mAP@0.5-0.95: 0.254505
#
# Epoch 197/200
# ----------
# Train:
# 60it [00:02, 25.58it/s]
#     box loss-> 0.00469, object loss-> 0.00625, class loss-> 0.00000
# Validation:
# 30it [00:01, 21.64it/s]
#     recall: 0.600000 precision: 0.616551 mAP@0.5: 0.629687, mAP@0.5-0.95: 0.257086
#
# Epoch 198/200
# ----------
# Train:
# 60it [00:02, 21.93it/s]
#     box loss-> 0.00462, object loss-> 0.00615, class loss-> 0.00000
# Validation:
# 30it [00:01, 29.15it/s]
#     recall: 0.600000 precision: 0.645327 mAP@0.5: 0.641771, mAP@0.5-0.95: 0.251920
#
# Epoch 199/200
# ----------
# Train:
# 60it [00:02, 25.46it/s]
#     box loss-> 0.00470, object loss-> 0.00621, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.38it/s]
#     recall: 0.542857 precision: 0.686379 mAP@0.5: 0.629069, mAP@0.5-0.95: 0.250572
#
# Epoch 200/200
# ----------
# Train:
# 60it [00:02, 26.00it/s]
#     box loss-> 0.00456, object loss-> 0.00615, class loss-> 0.00000
# Validation:
# 30it [00:01, 28.72it/s]
#     recall: 0.600000 precision: 0.625974 mAP@0.5: 0.635460, mAP@0.5-0.95: 0.253156
#
# Training completed in 20m 18s

# %%
dtr5 = CustomObjectDetection()
dtr5.setModelTypeAsTinyYOLOv3()
dtr5.setModelPath("/content/hololens-yolo/models/tiny-yolov3_hololens-yolo_last.pt")
dtr5.setJsonPath( "/content/hololens-yolo/json/hololens-yolo_tiny-yolov3_detection_config.json")
dtr5.loadModel()

# %%
detections = dtr5.detectObjectsFromImage(input_image="OD_img3.jpg",
                                         output_image_path="result_img3.jpg")
for d in detections:
    print(d["name"]," : ",d["percentage_probability"]," : ",d["box_points"])
plt.axis('off')
_=plt.imshow(Image.open("result_img3.jpg"))
_=plt.show()
# Out:
# hololens-yolo  :  46.34  :  [205, 223, 413, 335]
# hololens-yolo  :  51.46  :  [469, 189, 731, 335]

# %%
detections = dtr5.detectObjectsFromImage(input_image="OD_img4.jpg",
                                         output_image_path="result_img4.jpg")
for d in detections:
    print(d["name"]," : ",d["percentage_probability"]," : ",d["box_points"])
plt.axis('off')
_=plt.imshow(Image.open("result_img4.jpg"))
_=plt.show()
# Out:
# hololens-yolo  :  55.13  :  [180, 63, 251, 99]
# hololens-yolo  :  45.12  :  [590, 54, 756, 130]
# hololens-yolo  :  47.95  :  [12, 39, 84, 70]
# hololens-yolo  :  48.56  :  [439, 81, 520, 131]
# hololens-yolo  :  56.26  :  [363, 94, 441, 138]
# hololens-yolo  :  52.63  :  [176, 47, 255, 81]
# hololens-yolo  :  59.23  :  [367, 116, 431, 150]
# hololens-yolo  :  63.11  :  [17, 52, 85, 89]

# %%
detections = dtr5.detectObjectsFromImage(input_image="OD_img5.jpg",
                                         output_image_path="result_img5.jpg")
for d in detections:
    print(d["name"], " : ", d["percentage_probability"], " : ", d["box_points"])
plt.axis('off')
_=plt.imshow(Image.open("result_img5.jpg"))
_=plt.show()
# Out:
# hololens-yolo  :  53.04  :  [586, 110, 805, 246]
# hololens-yolo  :  54.1  :  [265, 132, 475, 258]
